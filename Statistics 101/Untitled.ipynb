# %%
import pandas as pd
import seaborn as sns
import numpy as np
import math
import matplotlib.pyplot as plt
from random import randint
import scipy.stats as ss
#from scipy.stats import norm, kurtosis, skew
import itertools as itt
sns.set(rc={'figure.figsize':(11.7,8.27)})
import plots

# %%
mu=0
sigma= 1.1
x = np.linspace(-4, 4, 5000)
y = ss.norm.pdf(x, mu, sigma)

# %%
def compute(lower, middle, high):
    between = []
    color = []
    between.append(np.where(np.round(x) == middle[0])[0][313])
    between.append(np.where(np.round(x) == middle[1])[0][313])
    color.append(np.where(np.round(x) == lower[0])[0][0])
    color.append(np.where(np.round(x) == lower[1])[0][313])
    color.append(np.where(np.round(x) == high[0])[0][313])
    color.append(np.where(np.round(x) == high[1])[0][-1])
    return between, color

# %%
def add_plots(ax, low, middle, high):
    color_in, color_out =compute(low, middle, high)
    ax.fill_between(x[color_in[0]:color_in[1]], 0, y[color_in[0]:color_in[1]], facecolor = 'blue')
    ax.fill_between(x[color_out[0]:color_out[1]], 0, y[color_out[0]:color_out[1]], facecolor ='green')
    ax.fill_between(x[color_out[2]:color_out[3]], 0, y[color_out[2]:color_out[3]], facecolor ='green')
    ax.plot(x,y)
fig1 = plt.figure()
ax4 = fig1.add_subplot(2,1,1)
add_plots(ax4, [-3,-2], [-2,2], [2,3])

# %%
add_plots(ax4, [-3,-2], [-2,2], [2,3])

# %%
def add_plots1(ax):
    low = [-3,-2]
    middle = [-2,2]
    high = [2,3]
    x, y ,color_in, color_out =compute(low, middle, high)
    ax.fill_between(x[color_in[0]:color_in[1]], 0, y[color_in[0]:color_in[1]], facecolor = 'blue')
    ax.fill_between(x[color_out[0]:color_out[1]], 0, y[color_out[0]:color_out[1]], facecolor ='green')
    ax.fill_between(x[color_out[2]:color_out[3]], 0, y[color_out[2]:color_out[3]], facecolor ='green')
    ax.plot(x,y)
add_plots1(ax4)

# %%
fig1 = plt.figure()
ax4 = fig1.add_subplot(2,1,1)
add_plots1(ax4)

# %%
mu=0
sigma= 1.1
x = np.linspace(-4, 4, 5000)
y = ss.norm.pdf(x, mu, sigma)

fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

def team(ax):
    mu=0
    sigma= 1.1
    x = np.linspace(-4, 4, 5000)
    y = ss.norm.pdf(x, mu, sigma)
    between = np.where(np.round(x) == -2)[0][313]
    between1 = np.where(np.round(x) == 2)[0][313]
    ax.plot(x,y)
    ax.fill_between(x[between:between1], 0, y[between:between1])
team(ax2)

# %%
fig1 = plt.figure()
ax4 = fig1.add_subplot(2,1,1)
def add_p(ax):
    ax.plot([1,2,3,4],[1,2,3,4])
    
add_p(ax4)

# %%
class Plots:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def test(self):
        print(str(self.x))

    def compute(self, lower, middle, high):
        between = []
        color = []
        between.append(np.where(np.round(self.x) == middle[0])[0][313])
        between.append(np.where(np.round(self.x) == middle[1])[0][313])
        color.append(np.where(np.round(self.x) == lower[0])[0][0])
        color.append(np.where(np.round(self.x) == lower[1])[0][313])
        color.append(np.where(np.round(self.x) == high[0])[0][313])
        color.append(np.where(np.round(self.x) == high[1])[0][-1])
        return between, color

    def add_plots(self,  ax, low, middle, high):
        color_in, color_out = self.compute([-3,-2], [-2,2], [2,3])
        #color_in, color_out = self.compute(low, middle, high)
        ax.plot(self.x, self.y)
        ax.fill_between(self.x[color_in[0]:color_in[1]], 0, self.y[color_in[0]:color_in[1]])
        ax.fill_between(self.x[color_out[0]:color_out[1]], 0, self.y[color_out[0]:color_out[1]], facecolor ='green')
        ax.fill_between(self.x[color_out[2]:color_out[3]], 0, self.y[color_out[2]:color_out[3]], facecolor ='green')
        return ax

# %%
fig1 = plt.figure()
ax4 = fig1.add_subplot(2,1,1)
P = Plots(x,y)
P.add_plots(ax4, [-3,-2], [-2,2], [2,3])

# %%
class Pet:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def test(self):
        print(str(self.x))

    def compute(self, lower, middle, high):
        return lower * middle* high

    def add_plots(self, low, middle, high):
        ax = self.compute(low, middle, high)
        return ax
    
I = Pet(1,2)
I.add_plots(1,2,3)
# Out:
# 6

# %%
fig1 = plt.figure()
ax4 = fig1.add_subplot(2,1,1)
ax5 = fig1.add_subplot(2,1,2)
add_plots1(ax4, [-3,-2], [-2,2], [2,3])
add_plots1(ax5, [-3,-2], [-2,2], [2,3])
